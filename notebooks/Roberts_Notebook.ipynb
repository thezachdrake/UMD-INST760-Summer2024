# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")
df.rename(columns=lambda x: x[0].lower() + x.strip().lower().replace(' ', '_')[1:], inplace=True)
df = df.convert_dtypes()
df
# Out:
#      2025_rank  2024_rank                              institution_name  \
# 0            1          1  Massachusetts Institute of Technology (MIT)
# 1            2          6                       Imperial College London
# 2            3          3                          University of Oxford
# 3            4          4                            Harvard University
# 4            5          2                       University of Cambridge
# ...        ...        ...                                           ...
# 1498     1401+  1201-1400               University of Montana Missoula
# 1499     1401+      1401+                          University of Oradea
# 1500     1401+  1201-1400                      University of San Carlos
# 1501     1401+      1401+      University Politehnica of Timisoara, UPT
# 1502     1401+      1401+                 Western Washington University
#
#      location   location_full size  academic_reputation  employer_reputation  \
# 0          US   United States    M                100.0                100.0
# 1          UK  United Kingdom    L                 98.5                 99.5
# 2          UK  United Kingdom    L                100.0                100.0
# 3          US   United States    L                100.0                100.0
# 4          UK  United Kingdom    L                100.0                100.0
# ...       ...             ...  ...                  ...                  ...
# 1498       US   United States    M                  3.0                  2.2
# 1499       RO         Romania    L                  5.6                  2.2
# 1500       PH     Philippines    M                  7.2                  9.4
# 1501       RO         Romania    L                  4.1                  4.2
# 1502       US   United States    L                  2.6                  2.6
#
#       faculty_student  citations_per_faculty  international_faculty  \
# 0               100.0                  100.0                   99.3
# 1                98.2                   93.9                  100.0
# 2               100.0                   84.8                   98.1
# 3                96.3                  100.0                   74.1
# 4               100.0                   84.6                  100.0
# ...               ...                    ...                    ...
# 1498             10.6                    6.1                    1.3
# 1499              4.0                    1.9                    1.5
# 1500              3.3                    1.8                    2.1
# 1501              7.2                    3.9                    1.4
# 1502              7.3                    3.5                    9.7
#
#       international_students  international_research_network  \
# 0                       86.8                            96.0
# 1                       99.6                            97.4
# 2                       97.7                           100.0
# 3                       69.0                            99.6
# 4                       94.8                            99.3
# ...                      ...                             ...
# 1498                     1.9                             6.5
# 1499                     5.2                            34.5
# 1500                     2.1                             6.4
# 1501                     2.5                            18.6
# 1502                     1.6                            12.4
#
#       employment_outcomes  sustainability qs_overall_score
# 0                   100.0            99.0              100
# 1                    93.4            99.7             98.5
# 2                   100.0            85.0             96.9
# 3                   100.0            84.4             96.8
# 4                   100.0            84.8             96.7
# ...                   ...             ...              ...
# 1498                  3.1             1.0                -
# 1499                  6.2             2.3                -
# 1500                  9.6             1.0                -
# 1501                  3.9             1.1                -
# 1502                  1.5             1.1                -
#
# [1503 rows x 16 columns]

# %% [markdown]
# Meet Eleanor. She’s an American college grad who values cultural diversity. She wants to go to grad school, but she’s having trouble sorting through all the college reports to figure out which one(s) she will apply to. So much information! It’s overwhelming!
#
# This is a big problem. She can only afford application fees for 3 schools. This is making her very nervous.
#
# So, she’s going to play the numbers game in order to quantify all this information and make an educated decision. She’s just that kind of person -- a science nerd.
#
# First, she knows she’s gotta figure out what she wants. She values cultural diversity. As a prospective environmental science major, sustainability is a must. She also wants to make sure that her tuition brings her the best bang for her buck, so professionalization and networking are really important to her.

# %%
sns.relplot(df)

# %% [markdown]
# A list of over 1500 schools, to which she plans on only applying to a handful, is simply too much data to root through by hand.
#
# She decides to identify her values first.
#
# *   Cultural diversity
# *   Environmental consciousness
# *   Professional development

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='international_faculty', y='international_students', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# There is no apparent correlation between international faculty and international student populations.

# %%
sns.catplot(y="institution_name", x="location", data=df, kind='bar')
plt.xlim(0, 10)
plt.xticks(rotation=90)
plt.yticks(rotation=360)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Eleanor decides that schools in France would be her best option, based on the criteria she has laid out. This makes a lot of sense!

# %%
#New dataset for all schools in France
France = df[df.location=="FR"]
France
# Out:
#       2025_rank  2024_rank                                   institution_name  \
# 63           63         59                                Sorbonne University
# 738     731-740    721-730                            Université Côte d\'Azur
# 733     721-730    631-640                                Université de Lille
# 882     851-900    771-780                               Université de Nantes
# 23           24         24                                     Université PSL
# 480         481        387                           Aix-Marseille University
# 721     711-720  1201-1400                        Université de Franche-Comté
# 858     851-900    851-900                          CY Cergy Paris University
# 404         405        392  Institut National des Sciences Appliquées de L...
# 204         205        192                          Ecole des Ponts ParisTech
# 734     721-730    711-720      Université de Rennes 1 (University of Rennes)
# 583         580        511              Université Paul Sabatier Toulouse III
# 302         302        236                              Université Paris Cité
# 536         535        465                             University of Bordeaux
# 457         456        421                           Université de Strasbourg
# 449         448        382                          Université de Montpellier
# 45           46         38                    Institut Polytechnique de Paris
# 1157  1001-1200  1201-1400                          Université Paris-Nanterre
# 282         283        328              Université Paris 1 Panthéon-Sorbonne
# 993    951-1000   951-1000                     Université Toulouse 1 Capitole
# 1360  1201-1400  1201-1400                      Université Jean Moulin Lyon 3
# 72           73         71                            Université Paris-Saclay
# 946     901-950    851-900                  University Paris 2 Panthéon-Assas
# 333         334        294                          Université Grenoble Alpes
# 1155  1001-1200  1001-1200                          Université Lumière Lyon 2
# 350         350        319                                       Sciences Po
# 836     801-850    721-730                             Université de Lorraine
# 186         187        184                   École Normale Supérieure de Lyon
# 1076  1001-1200  1001-1200                 Paul Valéry University Montpellier
# 992    951-1000      1401+                     Université Sorbonne Paris Nord
# 561         562        452                   Université Claude Bernard Lyon 1
# 1149  1001-1200  1001-1200                       Université de Caen Normandie
# 1150  1001-1200  1001-1200                             Université de Poitiers
# 1153  1001-1200  1001-1200                Université de Toulouse II-Le Mirail
# 1359  1201-1400  1201-1400                              Université de Limoges
#
#      location location_full size  academic_reputation  employer_reputation  \
# 63         FR        France   XL                 87.2                 52.0
# 738        FR        France   XL                 15.5                  4.1
# 733        FR        France   XL                 23.5                  5.5
# 882        FR        France   XL                 10.4                  3.4
# 23         FR        France    L                 74.4                 97.6
# 480        FR        France   XL                 36.9                  6.5
# 721        FR        France    S                  6.5                  2.1
# 858        FR        France    M                  3.7                  2.5
# 404        FR        France    M                  7.4                 28.7
# 204        FR        France    S                  8.9                 58.5
# 734        FR        France    L                 14.9                  5.2
# 583        FR        France    L                 17.7                  3.4
# 302        FR        France   XL                 27.8                  6.2
# 536        FR        France   XL                 31.3                  5.5
# 457        FR        France   XL                 39.1                 10.3
# 449        FR        France   XL                 18.6                  3.4
# 45         FR        France    M                 44.7                 99.6
# 1157       FR        France   XL                 11.4                  2.6
# 282        FR        France   XL                 65.6                 33.3
# 993        FR        France    L                 13.4                  4.6
# 1360       FR        France    L                  8.8                  5.2
# 72         FR        France   XL                 60.7                 99.1
# 946        FR        France    L                  7.1                  3.5
# 333        FR        France   XL                 44.7                 14.3
# 1155       FR        France    L                 10.1                  2.5
# 350        FR        France    L                 16.8                 34.8
# 836        FR        France   XL                 13.6                  3.3
# 186        FR        France    S                 29.8                 16.3
# 1076       FR        France    L                 11.8                  2.8
# 992        FR        France    L                  9.5                  4.1
# 561        FR        France   XL                 18.1                  3.7
# 1149       FR        France    L                  8.8                  2.8
# 1150       FR        France    L                  7.9                  1.7
# 1153       FR        France   XL                  9.4                  2.7
# 1359       FR        France    M                  6.6                  2.3
#
#       faculty_student  citations_per_faculty  international_faculty  \
# 63               43.0                   72.3                   33.8
# 738               5.7                   18.3                   29.3
# 733               4.8                   14.7                   14.6
# 882               7.8                   21.4                   19.8
# 23               98.1                   87.6                   62.3
# 480               7.9                   21.7                   17.5
# 721             100.0                   12.4                   <NA>
# 858              49.5                    5.0                   47.2
# 404              33.7                   60.6                   29.2
# 204              99.0                   62.6                   43.5
# 734              11.6                   28.3                   11.9
# 583              38.5                   28.0                    5.1
# 302               9.2                   87.0                   12.0
# 536              11.5                   17.6                   27.1
# 457               5.1                   20.7                   34.2
# 449               8.5                   57.2                   22.8
# 45               95.9                   86.1                   99.1
# 1157              3.3                    2.5                    8.6
# 282               4.6                    2.9                   34.3
# 993               1.7                    6.2                   25.5
# 1360              1.8                    2.3                   18.7
# 72               99.8                   35.0                   35.7
# 946              62.1                    1.2                   11.8
# 333               7.9                   41.7                   20.2
# 1155              4.5                    6.2                   26.7
# 350              81.1                    2.8                   52.7
# 836               7.0                   12.9                   27.6
# 186              97.0                   93.5                   59.0
# 1076              2.9                    5.3                    5.0
# 992               4.2                   29.3                   <NA>
# 561               7.9                   48.3                    7.4
# 1149              6.6                    6.3                    8.1
# 1150              5.4                    5.2                   <NA>
# 1153              1.3                    7.1                   27.2
# 1359             17.2                    5.5                   <NA>
#
#       international_students  international_research_network  \
# 63                      46.7                            99.8
# 738                     38.3                            78.4
# 733                     15.8                            93.3
# 882                     15.1                            87.3
# 23                      65.0                            99.8
# 480                     18.2                            99.1
# 721                     <NA>                            76.7
# 858                     45.9                            46.0
# 404                     58.3                            59.5
# 204                     96.5                            37.3
# 734                     11.0                            88.1
# 583                     21.5                            98.5
# 302                     35.2                            99.2
# 536                     23.3                            92.9
# 457                     35.9                            90.7
# 449                     29.9                            99.5
# 45                      98.0                            89.6
# 1157                     1.4                            56.9
# 282                     46.5                            70.3
# 993                     50.2                            52.6
# 1360                    30.2                             8.5
# 72                      58.6                            98.6
# 946                     26.1                             4.3
# 333                     35.1                            94.9
# 1155                    35.5                            59.1
# 350                     97.2                            31.4
# 836                     27.4                            95.9
# 186                     11.7                            70.3
# 1076                    32.2                            48.3
# 992                     <NA>                            61.0
# 561                     12.0                            93.7
# 1149                     6.2                            74.6
# 1150                    26.4                            75.3
# 1153                    19.7                            67.0
# 1359                    <NA>                            58.8
#
#       employment_outcomes  sustainability qs_overall_score  France
# 63                   79.7            87.6             70.3    True
# 738                   8.9            18.4                -    True
# 733                   4.5            10.9                -    True
# 882                   2.8             7.5                -    True
# 23                   97.1            73.4             84.7    True
# 480                  15.2            25.5               25    True
# 721                   3.2             1.7                -    True
# 858                   1.5             1.4                -    True
# 404                  14.4             2.4             29.3    True
# 204                  59.5            10.8             45.8    True
# 734                   6.8             6.9                -    True
# 583                   6.0            10.3             21.3    True
# 302                  15.2            18.4             35.9    True
# 536                  16.7            20.1             22.9    True
# 457                  20.4             5.4             26.3    True
# 449                  13.1            17.3             26.6    True
# 45                   97.7            54.8             77.5    True
# 1157                 29.1             1.6                -    True
# 282                  74.8            23.7             37.5    True
# 993                   6.1             1.8                -    True
# 1360                  4.4             1.0                -    True
# 72                   70.8            72.6               67    True
# 946                  53.1             1.0                -    True
# 333                  20.7            21.5             33.5    True
# 1155                  1.3             1.7                -    True
# 350                  97.7             7.2             32.5    True
# 836                  14.8            11.8                -    True
# 186                  14.0             6.6             47.5    True
# 1076                  2.1             2.8                -    True
# 992                   3.9             1.4                -    True
# 561                  12.4            11.0             22.2    True
# 1149                  2.1             1.9                -    True
# 1150                  6.7             2.1                -    True
# 1153                  2.1             1.2                -    True
# 1359                  2.9             1.1                -    True

# %%
# @title Sustainability in French schools

from matplotlib import pyplot as plt
France['sustainability'].plot(kind='hist', bins=20, title='sustainability')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
France['employment_outcomes'].plot(kind='hist', bins=20, title='employment outcomes')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Now that Eleanor has all the data she needs organized and displayed, it's time to put it all together!
#
# Since there are 4 schools in the top 100 that match her criteria, Eleanor decides to choose 4 instead of just to which to apply.

# %%
# top schools in France

sns.catplot(x="institution_name", y="2025_rank", data=France, kind="bar", ci=None)
plt.xlim(0, 3)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()
# Out:
# <ipython-input-70-7a2792196e5d>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x="institution_name", y="2025_rank", data=France, kind="bar", ci=None)

# %% [markdown]
# Success!
#
# Eleanor has identified the top schools to which to apply.
#
# 1.   Sorbonne University
# 1.   Université PSL
# 2.   Université Paris-Saclay
# 1.   Institut Polytechnique de Paris
#
# And she lived happily ever after.
